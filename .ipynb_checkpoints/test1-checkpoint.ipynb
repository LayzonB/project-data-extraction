# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("file1.csv")

# %%
data
# Out:
#       Unnamed: 0         ga:source                        ga:pagePath  \
# 0              0          (direct)                                  /
# 1              1          (direct)                                  /
# 2              2          (direct)                                  /
# 3              3          (direct)                                  /
# 4              4          (direct)                                  /
# ...          ...               ...                                ...
# 1709        1709       youtube.com          /recetas/recetas-de-cerdo
# 1710        1710       youtube.com          /recetas/recetas-de-cerdo
# 1711        1711       youtube.com           /recetas/recetas-rub-bbq
# 1712        1712       youtube.com  /recetas/salsas-mop-para-parrilla
# 1713        1713  za.pinterest.com                                  /
#
#        ga:date  ga:pageviews  ga:sessions  ga:users  ga:newUsers  \
# ...

# %%
data.shape
# Out:
# (1714, 11)

# %%
cols = list(null_cols[null_cols > 10000].index)
